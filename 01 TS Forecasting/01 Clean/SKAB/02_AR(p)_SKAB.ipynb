# %% [markdown]
# ## Загрузка необходимых библиотек

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error
from tqdm import tqdm


import warnings
warnings.filterwarnings("ignore")

# %%
def create_sequences(data, seq_lenght):
    X, y = [], []
    for i in range(len(data) - seq_lenght):
        X.append(data[i:(i+seq_lenght)])
        y.append(data[i+seq_lenght])
    return np.array(X), np.array(y)

# %% [markdown]
# ## Данные

# %% [markdown]
# Загрузка датасета временного ряда

# %%
df = pd.read_csv('../../../data/SKAB/anomaly-free/anomaly-free.csv', sep=';', index_col='datetime', parse_dates=True)

# %% [markdown]
# Визуализация временного ряда

# %%
df.plot(figsize=(20,8))
# Out:
# <Axes: xlabel='datetime'>

# %%
df.head()
# Out:
#                      Accelerometer1RMS  Accelerometer2RMS  Current  Pressure  \
# datetime
# 2020-02-08 13:30:47           0.202394           0.275154  2.16975  0.382638
# 2020-02-08 13:30:48           0.203153           0.277857  2.07999 -0.273216
# 2020-02-08 13:30:50           0.202054           0.275790  2.52577  0.382638
# 2020-02-08 13:30:51           0.203595           0.278101  2.49742  0.054711
# 2020-02-08 13:30:52           0.201889           0.276363  2.29194  0.710565
#
#                      Temperature  Thermocouple  Voltage  Volume Flow RateRMS
# datetime
# 2020-02-08 13:30:47      90.6454       26.8508  238.852              122.664
# 2020-02-08 13:30:48      90.7978       26.8639  227.943              122.338
# 2020-02-08 13:30:50      90.7730       26.8603  223.486              121.338
# 2020-02-08 13:30:51      90.8424       26.8616  244.904              121.664
# 2020-02-08 13:30:52      90.6664       26.8603  239.196              122.000

# %% [markdown]
# ## Анализ и прогнозирование временного ряда

# %% [markdown]
# ### Accelerometer1RMS

# %%
column = "Accelerometer1RMS"

# %%
# Тест и АКФ (ЧАКФ) для исходного ряда
ts = np.diff(df[column], n=0)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -3.6148769415417594
# 2. P-Value :  0.005482899762788733
# 3. Num Of Lags :  32

# %%
# Тест и АКФ (ЧАКФ) для дифференцированного временного ряда
ts = np.diff(df[column], n=1)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -21.094195351001105
# 2. P-Value :  0.0
# 3. Num Of Lags :  38

# %%
seq_lenght = dftest[2]
data = np.array(df[column])
X, y_true = create_sequences(data, seq_lenght)

# %%
p = 6
d = 1
q = 0

y_pred = []
for i in tqdm(range(len(X[:300]))):
    model = ARIMA(X[i], order=(p, d, q))
    model_fit = model.fit()
    pred = model_fit.predict(seq_lenght,seq_lenght, dynamic=False)
    y_pred.append(pred)
y_pred = np.array(y_pred)

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("MSE", column, mean_squared_error(y_true[:300], y_pred[:300]))
# Out:
# 100%|██████████| 300/300 [00:30<00:00,  9.81it/s]
# MSE Accelerometer1RMS 7.939231869358922e-07

# %% [markdown]
# ### Accelerometer2RMS

# %%
column = "Accelerometer2RMS"

# %%
# Тест и АКФ (ЧАКФ) для исходного ряда
ts = np.diff(df[column], n=0)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -2.8397000456255697
# 2. P-Value :  0.05282284534860737
# 3. Num Of Lags :  37

# %%
# Тест и АКФ (ЧАКФ) для дифференцированного временного ряда
ts = np.diff(df[column], n=1)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -23.603012312368246
# 2. P-Value :  0.0
# 3. Num Of Lags :  36

# %%
seq_lenght = dftest[2]
data = np.array(df[column])
X, y_true = create_sequences(data, seq_lenght)

# %%
p = 7
d = 1
q = 0

y_pred = []
for i in tqdm(range(len(X[:300]))):
    model = ARIMA(X[i], order=(p, d, q))
    model_fit = model.fit()
    pred = model_fit.predict(seq_lenght,seq_lenght, dynamic=False)
    y_pred.append(pred)
y_pred = np.array(y_pred)
fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("MSE", column, mean_squared_error(y_true[:300], y_pred[:300]))
# Out:
# 100%|██████████| 300/300 [00:36<00:00,  8.32it/s]
# MSE Accelerometer2RMS 1.3293311540442383e-06

# %% [markdown]
# ### Current

# %%
column = "Current"

# %%
# Тест и АКФ (ЧАКФ) для исходного ряда
ts = np.diff(df[column], n=0)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -20.595541347265833
# 2. P-Value :  0.0
# 3. Num Of Lags :  26

# %%
# Тест и АКФ (ЧАКФ) для дифференцированного временного ряда
ts = np.diff(df[column], n=1)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -28.512055139104124
# 2. P-Value :  0.0
# 3. Num Of Lags :  38

# %%
seq_lenght = dftest[2]
data = np.array(df[column])
X, y_true = create_sequences(data, seq_lenght)

# %%
p = 7
d = 0
q = 0

y_pred = []
for i in tqdm(range(len(X[:300]))):
    model = ARIMA(X[i], order=(p, d, q))
    model_fit = model.fit()
    pred = model_fit.predict(seq_lenght,seq_lenght, dynamic=False)
    y_pred.append(pred)
y_pred = np.array(y_pred)
fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("MSE", column, mean_squared_error(y_true[:300], y_pred[:300]))
# Out:
# 100%|██████████| 300/300 [00:33<00:00,  8.84it/s]
# MSE Current 1.2584996165871016e-06

# %% [markdown]
# ### Pressure

# %%
column = "Pressure"

# %%
# Тест и АКФ (ЧАКФ) для исходного ряда
ts = np.diff(df[column], n=0)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -87.11789866136489
# 2. P-Value :  0.0
# 3. Num Of Lags :  0

# %%
# Тест и АКФ (ЧАКФ) для дифференцированного временного ряда
ts = np.diff(df[column], n=1)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -26.820203172949487
# 2. P-Value :  0.0
# 3. Num Of Lags :  38

# %%
seq_lenght = dftest[2]
data = np.array(df[column])
X, y_true = create_sequences(data, seq_lenght)

# %%
p = 2
d = 0
q = 0

y_pred = []
for i in tqdm(range(len(X[:300]))):
    model = ARIMA(X[i], order=(p, d, q))
    model_fit = model.fit()
    pred = model_fit.predict(seq_lenght,seq_lenght, dynamic=False)
    y_pred.append(pred)
y_pred = np.array(y_pred)
fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("MSE", column, mean_squared_error(y_true[:300], y_pred[:300]))
# Out:
# 100%|██████████| 300/300 [00:07<00:00, 40.02it/s]
# MSE Pressure 0.05880742858813013

# %% [markdown]
# ### Temperature

# %%
column = "Temperature"

# %%
# Тест и АКФ (ЧАКФ) для исходного ряда
ts = np.diff(df[column], n=0)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -4.737769371176162
# 2. P-Value :  7.142821405574464e-05
# 3. Num Of Lags :  38

# %%
# Тест и АКФ (ЧАКФ) для дифференцированного временного ряда
ts = np.diff(df[column], n=1)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -22.115447226620624
# 2. P-Value :  0.0
# 3. Num Of Lags :  38

# %%
seq_lenght = dftest[2]
data = np.array(df[column])
X, y_true = create_sequences(data, seq_lenght)

# %%
p = 6
d = 0
q = 0

y_pred = []
for i in tqdm(range(len(X[:300]))):
    model = ARIMA(X[i], order=(p, d, q))
    model_fit = model.fit()
    pred = model_fit.predict(seq_lenght,seq_lenght, dynamic=False)
    y_pred.append(pred)
y_pred = np.array(y_pred)
fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("MSE", column, mean_squared_error(y_true[:300], y_pred[:300]))
# Out:
# 100%|██████████| 300/300 [00:25<00:00, 11.64it/s]
# MSE Temperature 0.05192815660488439

# %% [markdown]
# ### Thermocouple

# %%
column = "Thermocouple"

# %%
# Тест и АКФ (ЧАКФ) для исходного ряда
ts = np.diff(df[column], n=0)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -3.518532369822394
# 2. P-Value :  0.007523705889989444
# 3. Num Of Lags :  19

# %%
# Тест и АКФ (ЧАКФ) для дифференцированного временного ряда
ts = np.diff(df[column], n=1)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -22.30589147579151
# 2. P-Value :  0.0
# 3. Num Of Lags :  18

# %%
seq_lenght = dftest[2]
data = np.array(df[column])
X, y_true = create_sequences(data, seq_lenght)

# %%
p = 3
d = 1
q = 0

y_pred = []
for i in tqdm(range(len(X[:300]))):
    model = ARIMA(X[i], order=(p, d, q))
    model_fit = model.fit()
    pred = model_fit.predict(seq_lenght,seq_lenght, dynamic=False)
    y_pred.append(pred)
y_pred = np.array(y_pred)
fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("MSE", column, mean_squared_error(y_true[:300], y_pred[:300]))
# Out:
# 100%|██████████| 300/300 [00:17<00:00, 16.74it/s]
# MSE Thermocouple 3.98541406215055e-05

# %% [markdown]
# ### Voltage

# %%
column = "Voltage"

# %%
# Тест и АКФ (ЧАКФ) для исходного ряда
ts = np.diff(df[column], n=0)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -96.05731098378851
# 2. P-Value :  0.0
# 3. Num Of Lags :  0

# %%
# Тест и АКФ (ЧАКФ) для дифференцированного временного ряда
ts = np.diff(df[column], n=1)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -27.84704054808692
# 2. P-Value :  0.0
# 3. Num Of Lags :  38

# %%
seq_lenght = dftest[2]
data = np.array(df[column])
X, y_true = create_sequences(data, seq_lenght)

# %%
p = 2
d = 0
q = 0

y_pred = []
for i in tqdm(range(len(X[:300]))):
    model = ARIMA(X[i], order=(p, d, q))
    model_fit = model.fit()
    pred = model_fit.predict(seq_lenght,seq_lenght, dynamic=False)
    y_pred.append(pred)
y_pred = np.array(y_pred)
fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("MSE", column, mean_squared_error(y_true[:300], y_pred[:300]))
# Out:
# 100%|██████████| 300/300 [00:06<00:00, 42.87it/s]
# MSE Voltage 125.80091786871184

# %% [markdown]
# ### Volume Flow RateRMS

# %%
column = "Volume Flow RateRMS"

# %%
# Тест и АКФ (ЧАКФ) для исходного ряда
ts = np.diff(df[column], n=0)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -3.244626381897769
# 2. P-Value :  0.017542551951679582
# 3. Num Of Lags :  18

# %%
# Тест и АКФ (ЧАКФ) для дифференцированного временного ряда
ts = np.diff(df[column], n=1)
dftest = adfuller(ts)
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print()
plot_pacf(ts);
# Out:
# 1. ADF :  -29.00939117410992
# 2. P-Value :  0.0
# 3. Num Of Lags :  19

# %%
seq_lenght = dftest[2]
data = np.array(df[column])
X, y_true = create_sequences(data, seq_lenght)

# %%
p = 8
d = 1
q = 0

y_pred = []
for i in tqdm(range(len(X[:300]))):
    model = ARIMA(X[i], order=(p, d, q))
    model_fit = model.fit()
    pred = model_fit.predict(seq_lenght,seq_lenght, dynamic=False)
    y_pred.append(pred)
y_pred = np.array(y_pred)
fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("MSE", column, mean_squared_error(y_true[:300], y_pred[:300]))
# Out:
# 100%|██████████| 300/300 [00:32<00:00,  9.35it/s]
# MSE Volume Flow RateRMS 0.33478655516635425
