# %%
# !pip install statsforecast

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from statsforecast import StatsForecast
from statsforecast.models import AutoARIMA
from sklearn.metrics import mean_squared_error
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('https://raw.githubusercontent.com/demosss/TSL/main/data/SKAB/anomaly-free/anomaly-free.csv', sep=';')

# %%
def create_sequences(data, column, seq_lenght):
    X, y = [], []
    for i in range(len(data) - seq_lenght):
        df_seq = data[['datetime', column]][i:i+seq_lenght]
        df_seq.columns = ['ds', 'y']
        df_seq['unique_id'] = column
        X.append(df_seq)
        y.append(data[column][i+seq_lenght])
    return X, np.array(y)

# %% [markdown]
# ### Accelerometer1RMS

# %%
column = 'Accelerometer1RMS'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [AutoARIMA(season_length = 0)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['AutoARIMA'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Accelerometer1RMS 0.0012329865252237303

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Accelerometer2RMS

# %%
column = 'Accelerometer2RMS'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [AutoARIMA(season_length = 0)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['AutoARIMA'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Accelerometer2RMS 0.0013088783011679394

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Current

# %%
column = 'Current'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [AutoARIMA(season_length = 0)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['AutoARIMA'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Current 0.5077664067811524

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Pressure

# %%
column = 'Pressure'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [AutoARIMA(season_length = 0)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['AutoARIMA'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Pressure 0.25495040432404587

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Temperature

# %%
column = 'Temperature'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [AutoARIMA(season_length = 0)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['AutoARIMA'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Temperature 0.22118699830080268

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Thermocouple

# %%
column = 'Thermocouple'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [AutoARIMA(season_length = 0)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['AutoARIMA'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Thermocouple 0.006206104075326817

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Voltage

# %%
column = 'Voltage'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [AutoARIMA(season_length = 0)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['AutoARIMA'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Voltage 11.376139060942192

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Volume Flow RateRMS

# %%
column = 'Volume Flow RateRMS'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [AutoARIMA(season_length = 0)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['AutoARIMA'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Volume Flow RateRMS 0.4577156502271938

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# # Полный расчет по всем временным рядам

# %%
columns = ['Accelerometer1RMS', 'Accelerometer2RMS', 'Current', 'Pressure', 'Temperature', 'Thermocouple', 'Voltage', 'Volume Flow RateRMS']

for column in columns:
    print(column)

    X, y_true = create_sequences(df, column, 30)
    sf = StatsForecast(models = [AutoARIMA(season_length = 0)], freq = 'S')
    y_pred = []
    for i in tqdm(range(len(X))):
        sf.fit(X[i])
        forecast_df = sf.forecast(h=1)
        y_pred.append(forecast_df['AutoARIMA'][0])

    print("RMSE", column, mean_squared_error(y_true, y_pred) ** 0.5)
    print()
# Out:
# Accelerometer1RMS
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Accelerometer1RMS 0.0014507155030908947
#
# Accelerometer2RMS
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Accelerometer2RMS 0.0014984968161286913
#
# Current
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Current 0.5124357421952402
#
# Pressure
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Pressure 0.2769440853564333
#
# Temperature
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Temperature 0.21096361441673503
#
# Thermocouple
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Thermocouple 0.006230491415903078
#
# Voltage
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Voltage 11.669226419840017
#
# Volume Flow RateRMS
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Volume Flow RateRMS 0.47707363900421235
