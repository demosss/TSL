# %%
# !pip install statsforecast

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from statsforecast import StatsForecast
from statsforecast.models import SeasonalExponentialSmoothing
from sklearn.metrics import mean_squared_error
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('https://raw.githubusercontent.com/demosss/TSL/main/data/SKAB/anomaly-free/anomaly-free.csv', sep=';')

# %%
def create_sequences(data, column, seq_lenght):
    X, y = [], []
    for i in range(len(data) - seq_lenght):
        df_seq = data[['datetime', column]][i:i+seq_lenght]
        df_seq.columns = ['ds', 'y']
        df_seq['unique_id'] = column
        X.append(df_seq)
        y.append(data[column][i+seq_lenght])
    return X, np.array(y)

# %% [markdown]
# ### Accelerometer1RMS

# %%
column = 'Accelerometer1RMS'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [SeasonalExponentialSmoothing(alpha=0.8, season_length=1)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['SeasonalES'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Accelerometer1RMS 0.0014738066905959483

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Accelerometer2RMS

# %%
column = 'Accelerometer2RMS'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [SeasonalExponentialSmoothing(alpha=0.8, season_length=1)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['SeasonalES'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Accelerometer2RMS 0.0015890092703548652

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Current

# %%
column = 'Current'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [SeasonalExponentialSmoothing(alpha=0.8, season_length=1)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['SeasonalES'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Current 0.6123964542369155

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Pressure

# %%
column = 'Pressure'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [SeasonalExponentialSmoothing(alpha=0.8, season_length=1)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['SeasonalES'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Pressure 0.28700850646744225

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Temperature

# %%
column = 'Temperature'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [SeasonalExponentialSmoothing(alpha=0.8, season_length=1)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['SeasonalES'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Temperature 0.22242726731927337

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Thermocouple

# %%
column = 'Thermocouple'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [SeasonalExponentialSmoothing(alpha=0.8, season_length=1)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['SeasonalES'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Thermocouple 0.006628349128962679

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Voltage

# %%
column = 'Voltage'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [SeasonalExponentialSmoothing(alpha=0.8, season_length=1)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['SeasonalES'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Voltage 14.547184377568092

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Volume Flow RateRMS

# %%
column = 'Volume Flow RateRMS'
X, y_true = create_sequences(df, column, 30)
sf = StatsForecast(models = [SeasonalExponentialSmoothing(alpha=0.8, season_length=1)], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    sf.fit(X[i])
    forecast_df = sf.forecast(h=1)
    y_pred.append(forecast_df['SeasonalES'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Volume Flow RateRMS 0.4858703752961963

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# # Полный расчет по всем временным рядам

# %%
columns = ['Accelerometer1RMS', 'Accelerometer2RMS', 'Current', 'Pressure', 'Temperature', 'Thermocouple', 'Voltage', 'Volume Flow RateRMS']

for column in columns:
    print(column)

    X, y_true = create_sequences(df, column, 30)
    sf = StatsForecast(models = [SeasonalExponentialSmoothing(alpha=0.8, season_length=1)], freq = 'S')
    y_pred = []
    for i in tqdm(range(len(X))):
        sf.fit(X[i])
        forecast_df = sf.forecast(h=1)
        y_pred.append(forecast_df['SeasonalES'][0])

    print("RMSE", column, mean_squared_error(y_true, y_pred) ** 0.5)
    print()
# Out:
# Accelerometer1RMS
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Accelerometer1RMS 0.001607622481886318
#
# Accelerometer2RMS
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Accelerometer2RMS 0.0016733836659530816
#
# Current
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Current 0.6040739656687939
#
# Pressure
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Pressure 0.31257972601408973
#
# Temperature
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Temperature 0.21651062017463527
#
# Thermocouple
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Thermocouple 0.006167541683754123
#
# Voltage
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Voltage 14.134040563612508
#
# Volume Flow RateRMS
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Volume Flow RateRMS 0.4835421499372859
