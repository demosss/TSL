# %%
# !pip install mlforecast
# Out:
# Requirement already satisfied: mlforecast in c:\programdata\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: numba in c:\programdata\anaconda3\lib\site-packages (from mlforecast) (0.57.1)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from mlforecast) (2.0.3)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from mlforecast) (1.3.0)
# Requirement already satisfied: utilsforecast>=0.0.6 in c:\programdata\anaconda3\lib\site-packages (from mlforecast) (0.0.19)
# Requirement already satisfied: window-ops in c:\programdata\anaconda3\lib\site-packages (from mlforecast) (0.0.14)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from utilsforecast>=0.0.6->mlforecast) (1.24.3)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from utilsforecast>=0.0.6->mlforecast) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->mlforecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->mlforecast) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->mlforecast) (2023.3)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\programdata\anaconda3\lib\site-packages (from numba->mlforecast) (0.40.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->mlforecast) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->mlforecast) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->mlforecast) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->mlforecast) (1.16.0)

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from mlforecast import MLForecast
import lightgbm as lgb
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/demosss/TSL/main/data/SKAB/anomaly-free/anomaly-free.csv', sep=';')

# %%
def create_sequences(data, column, seq_lenght):
    X, y = [], []
    for i in range(len(data) - seq_lenght):
        df_seq = data[['datetime', column]][i:i+seq_lenght]
        df_seq.columns = ['ds', 'y']
        df_seq['unique_id'] = column
        df_seq['ds'] = df_seq['ds'].astype("datetime64[s]")
        X.append(df_seq)
        y.append(data[column][i+seq_lenght])
    return X, np.array(y)

# %% [markdown]
# ### Accelerometer1RMS

# %%
column = 'Accelerometer1RMS'
X, y_true = create_sequences(df, column, 30)
mlf = MLForecast(models=LinearRegression(), lags=[10], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    mlf.fit(X[i])
    forecast_df = mlf.predict(1)
    y_pred.append(forecast_df['LinearRegression'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Accelerometer1RMS 0.0012020669099000903

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Accelerometer2RMS

# %%
column = 'Accelerometer2RMS'
X, y_true = create_sequences(df, column, 30)
mlf = MLForecast(models=LinearRegression(), lags=[10], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    mlf.fit(X[i])
    forecast_df = mlf.predict(1)
    y_pred.append(forecast_df['LinearRegression'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Accelerometer2RMS 0.0012348069135052614

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Current

# %%
column = 'Current'
X, y_true = create_sequences(df, column, 30)
mlf = MLForecast(models=LinearRegression(), lags=[10], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    mlf.fit(X[i])
    forecast_df = mlf.predict(1)
    y_pred.append(forecast_df['LinearRegression'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Current 0.5267023812103759

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Pressure

# %%
column = 'Pressure'
X, y_true = create_sequences(df, column, 30)
mlf = MLForecast(models=LinearRegression(), lags=[10], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    mlf.fit(X[i])
    forecast_df = mlf.predict(1)
    y_pred.append(forecast_df['LinearRegression'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Pressure 0.25079592530772865

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Temperature

# %%
column = 'Temperature'
X, y_true = create_sequences(df, column, 30)
mlf = MLForecast(models=LinearRegression(), lags=[10], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    mlf.fit(X[i])
    forecast_df = mlf.predict(1)
    y_pred.append(forecast_df['LinearRegression'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Temperature 0.23978917220813398

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Thermocouple

# %%
column = 'Thermocouple'
X, y_true = create_sequences(df, column, 30)
mlf = MLForecast(models=LinearRegression(), lags=[10], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    mlf.fit(X[i])
    forecast_df = mlf.predict(1)
    y_pred.append(forecast_df['LinearRegression'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Thermocouple 0.007053298018916299

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Voltage

# %%
column = 'Voltage'
X, y_true = create_sequences(df, column, 30)
mlf = MLForecast(models=LinearRegression(), lags=[10], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    mlf.fit(X[i])
    forecast_df = mlf.predict(1)
    y_pred.append(forecast_df['LinearRegression'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Voltage 11.326696564234528

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# ### Volume Flow RateRMS

# %%
column = 'Volume Flow RateRMS'
X, y_true = create_sequences(df, column, 30)
mlf = MLForecast(models=LinearRegression(), lags=[10], freq = 'S')
y_pred = []
for i in tqdm(range(len(X[:300]))):
    mlf.fit(X[i])
    forecast_df = mlf.predict(1)
    y_pred.append(forecast_df['LinearRegression'][0])

fig = plt.figure(figsize=(20, 8))
plt.plot(y_true[:300], label = "Истинные значения")
plt.plot(y_pred[:300], label = "Предсказанные значения")
plt.legend()
plt.show()

print("RMSE", column, mean_squared_error(y_true[:300], y_pred[:300]) ** 0.5)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# RMSE Volume Flow RateRMS 0.4509186796120002

# %%
resudials = y_true[:300] - y_pred[:300]
sns.histplot(data=resudials, kde=True, bins=30)
plt.show()

# %% [markdown]
# # Полный расчет по всем временным рядам

# %%
columns = ['Accelerometer1RMS', 'Accelerometer2RMS', 'Current', 'Pressure', 'Temperature', 'Thermocouple', 'Voltage', 'Volume Flow RateRMS']

for column in columns:
    print(column)

    X, y_true = create_sequences(df, column, 30)
    mlf = MLForecast(models=LinearRegression(), lags=[2], freq = 'S')
    y_pred = []
    for i in tqdm(range(len(X))):
        mlf.fit(X[i])
        forecast_df = mlf.predict(1)
        y_pred.append(forecast_df['LinearRegression'][0])

    print("RMSE", column, mean_squared_error(y_true, y_pred) ** 0.5)
    print()
# Out:
# Accelerometer1RMS
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Accelerometer1RMS 0.0013184244103392842
#
# Accelerometer2RMS
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Accelerometer2RMS 0.0012813432933452117
#
# Current
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Current 0.5061481413423554
#
# Pressure
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Pressure 0.263112454585792
#
# Temperature
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Temperature 0.23296973309867464
#
# Thermocouple
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Thermocouple 0.0072287940686564835
#
# Voltage
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Voltage 11.404150672349829
#
# Volume Flow RateRMS
#   0%|          | 0/9375 [00:00<?, ?it/s]
# RMSE Volume Flow RateRMS 0.4667898783510153
